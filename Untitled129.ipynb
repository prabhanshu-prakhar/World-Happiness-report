# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tdf = pd.read_csv("globalterrorismdb_0718dist.csv",encoding='ISO-8859-1')
# Out:
# C:\Users\prabh\AppData\Local\Temp\ipykernel_2000\338915982.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   tdf = pd.read_csv("globalterrorismdb_0718dist.csv",encoding='ISO-8859-1')

# %%
hr = pd.read_csv("2015.csv")

# %%
hr.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
tdf.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
names = ['eventid','iyear','imonth','iday','country_txt','region_txt','provstate','city','attacktype1_txt','targtype1_txt','weaptype1_txt','nkill','nwound','property','propextent_txt','propvalue']

# %%
names = ['eventid', 'iyear', 'imonth', 'iday', 'country_txt', 'region_txt', 
         'provstate', 'city', 'attacktype1_txt', 'targtype1_txt', 'weaptype1_txt', 
         'nkill', 'nwound', 'property', 'propextent_txt', 'propvalue']

columns_to_keep = [column for column in tdf.columns if column in names]

tdf = tdf[columns_to_keep]

print(tdf)
# Out:
#              eventid  iyear  imonth  iday         country_txt  \
# 0       197000000001   1970       7     2  Dominican Republic
# 1       197000000002   1970       0     0              Mexico
# 2       197001000001   1970       1     0         Philippines
# 3       197001000002   1970       1     0              Greece
# 4       197001000003   1970       1     0               Japan
# ...              ...    ...     ...   ...                 ...
# 181686  201712310022   2017      12    31             Somalia
# 181687  201712310029   2017      12    31               Syria
# 181688  201712310030   2017      12    31         Philippines
# 181689  201712310031   2017      12    31               India
# 181690  201712310032   2017      12    31         Philippines
#
#                          region_txt        provstate           city  \
# 0       Central America & Caribbean              NaN  Santo Domingo
# 1                     North America          Federal    Mexico city
# ...

# %%
tdf.head(100)
# Out:
#          eventid  iyear  imonth  iday         country_txt  \
# 0   197000000001   1970       7     2  Dominican Republic
# 1   197000000002   1970       0     0              Mexico
# 2   197001000001   1970       1     0         Philippines
# 3   197001000002   1970       1     0              Greece
# 4   197001000003   1970       1     0               Japan
# ..           ...    ...     ...   ...                 ...
# 95  197002280001   1970       2    28              Jordan
# 96  197003000001   1970       3     0         Philippines
# 97  197003010001   1970       3     1               Italy
# 98  197003010005   1970       3     1       United States
# 99  197003010006   1970       3     1       United States
#
#                      region_txt             provstate              city  \
# 0   Central America & Caribbean                   NaN     Santo Domingo
# 1                 North America               Federal       Mexico city
# ...

# %%
tdf.isnull().sum()
# Out:
# eventid                 0
# iyear                   0
# imonth                  0
# iday                    0
# country_txt             0
# region_txt              0
# provstate             421
# city                  434
# attacktype1_txt         0
# targtype1_txt           0
# weaptype1_txt           0
# nkill               10313
# nwound              16311
# property                0
# propextent_txt     117626
# propvalue          142702
# dtype: int64

# %%
tdf.value_counts()
# Out:
# eventid       iyear  imonth  iday  country_txt    region_txt                  provstate                            city         attacktype1_txt                 targtype1_txt                   weaptype1_txt  nkill  nwound  property  propextent_txt               propvalue
# 197001020002  1970   1       2     United States  North America               California                           Oakland      Bombing/Explosion               Utilities                       Explosives     0.0    0.0     1         Minor (likely < $1 million)   22500.0     1
# 201411250029  2014   11      25    Pakistan       South Asia                  Federally Administered Tribal Areas  Shah Kas     Unknown                         Military                        Unknown        1.0    1.0     1         Unknown                      -99.0        1
# ...

# %%
tdf.shape[0]
# Out:
# 181691

# %%
tdf.dtypes
# Out:
# eventid              int64
# iyear                int64
# imonth               int64
# iday                 int64
# country_txt         object
# region_txt          object
# provstate           object
# city                object
# attacktype1_txt     object
# targtype1_txt       object
# weaptype1_txt       object
# nkill              float64
# nwound             float64
# property             int64
# propextent_txt      object
# propvalue          float64
# dtype: object

# %%
y = tdf.groupby('iyear')['eventid'].size()

# %%
y
# Out:
# iyear
# 1970      651
# 1971      471
# 1972      568
# 1973      473
# 1974      581
# 1975      740
# 1976      923
# 1977     1319
# 1978     1526
# 1979     2662
# 1980     2662
# 1981     2586
# 1982     2544
# 1983     2870
# 1984     3495
# 1985     2915
# 1986     2860
# 1987     3183
# 1988     3721
# 1989     4324
# 1990     3887
# 1991     4683
# 1992     5071
# 1994     3456
# 1995     3081
# 1996     3058
# 1997     3197
# 1998      934
# 1999     1395
# 2000     1814
# 2001     1906
# 2002     1333
# 2003     1278
# 2004     1166
# 2005     2017
# 2006     2758
# 2007     3242
# 2008     4805
# 2009     4721
# 2010     4826
# 2011     5076
# 2012     8522
# 2013    12036
# 2014    16903
# 2015    14965
# 2016    13587
# 2017    10900
# Name: eventid, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(data=tdf, x = 'iyear')  # Specify the 'year' column for the x-axis
plt.title("Year Wise Incidents")
plt.xlabel("Year")
plt.ylabel("Incidents")
plt.show()

# %%
df = tdf.drop_duplicates()

# %%
df
# Out:
#              eventid  iyear  imonth  iday         country_txt  \
# 0       197000000001   1970       7     2  Dominican Republic
# 1       197000000002   1970       0     0              Mexico
# 2       197001000001   1970       1     0         Philippines
# 3       197001000002   1970       1     0              Greece
# 4       197001000003   1970       1     0               Japan
# ...              ...    ...     ...   ...                 ...
# 181686  201712310022   2017      12    31             Somalia
# 181687  201712310029   2017      12    31               Syria
# 181688  201712310030   2017      12    31         Philippines
# 181689  201712310031   2017      12    31               India
# 181690  201712310032   2017      12    31         Philippines
#
#                          region_txt        provstate           city  \
# 0       Central America & Caribbean              NaN  Santo Domingo
# 1                     North America          Federal    Mexico city
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(data=df, x = 'iyear')  # Specify the 'year' column for the x-axis
plt.title("Year Wise Incidents")
plt.xlabel("Year")
plt.ylabel("Incidents")
plt.show()

# %%
c = df.groupby('country_txt')['eventid'].size()

# %%
c
# Out:
# country_txt
# Afghanistan    12731
# Albania           80
# Algeria         2743
# Andorra            1
# Angola           499
#                ...
# Yemen           3347
# Yugoslavia       203
# Zaire             50
# Zambia            62
# Zimbabwe         101
# Name: eventid, Length: 205, dtype: int64

# %%
# Sort the result in descending order
c_sorted = c.sort_values(ascending=False)

print(c_sorted)
# Out:
# country_txt
# Iraq                   24636
# Pakistan               14368
# Afghanistan            12731
# India                  11960
# Colombia                8306
#                        ...
# Antigua and Barbuda        1
# New Hebrides               1
# St. Lucia                  1
# South Vietnam              1
# North Korea                1
# Name: eventid, Length: 205, dtype: int64

# %%
c_sorted.head(10)
# Out:
# country_txt
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: eventid, dtype: int64

# %%
hr=pd.read_csv("2015.csv")

# %%
hr.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
hr.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
hrf  = hr.sort_values(by = 'Happiness Rank', ascending = True)

# %%
hrf
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
hrf.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %%
sns.scatterplot(x ='Economy (GDP per Capita)', y = 'Happiness Score', data  = hr)
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Happiness Score'>

# %%
tdf.groupby('attacktype1_txt')['eventid'].size()
# Out:
# attacktype1_txt
# Armed Assault                          42669
# Assassination                          19312
# Bombing/Explosion                      88255
# Facility/Infrastructure Attack         10356
# Hijacking                                659
# Hostage Taking (Barricade Incident)      991
# Hostage Taking (Kidnapping)            11158
# Unarmed Assault                         1015
# Unknown                                 7276
# Name: eventid, dtype: int64

# %%
plt.figure(figsize=(15,10))

sns.histplot(data = tdf, x = 'attacktype1_txt')
# Out:
# <AxesSubplot:xlabel='attacktype1_txt', ylabel='Count'>

# %%
plt.figure(figsize=(15,10))

sns.barplot(data = tdf, x = 'attacktype1_txt')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [32], in <cell line: 3>()
#       1 plt.figure(figsize=(15,10))
# ----> 3 sns.barplot(data = tdf, x = 'attacktype1_txt')
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~\anaconda3\lib\site-packages\seaborn\categorical.py:3182, in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
# ...

# %%
incident_counts = df['attacktype1_txt'].value_counts()

incident_counts_df = incident_counts.reset_index()
incident_counts_df.columns = ['Attack_Type', 'Number_of_Incidents']

plt.figure(figsize=(12, 8))
sns.barplot(x='Number_of_Incidents', y='Attack_Type', data=incident_counts_df, palette='viridis')

plt.title('Number of Incidents by Attack Type')
plt.xlabel('Number of Incidents')
plt.ylabel('Attack Type')

plt.show()

# %%
incident_counts = df['attacktype1_txt'].value_counts()

# %%
incident_counts
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: attacktype1_txt, dtype: int64

# %%
incident_counts_df = incident_counts.reset_index()
incident_counts_df.columns = ['Attack_Type', 'Number_of_Incidents']

# %%
incident_counts_df
# Out:
#                            Attack_Type  Number_of_Incidents
# 0                    Bombing/Explosion                88255
# 1                        Armed Assault                42669
# 2                        Assassination                19312
# 3          Hostage Taking (Kidnapping)                11158
# 4       Facility/Infrastructure Attack                10356
# 5                              Unknown                 7276
# 6                      Unarmed Assault                 1015
# 7  Hostage Taking (Barricade Incident)                  991
# 8                            Hijacking                  659

# %%
cross_tab = pd.crosstab(tdf['region_txt'], tdf['attacktype1_txt'])

plt.figure(figsize=(12, 8))
sns.heatmap(cross_tab, annot=True, fmt='d', cmap='YlGnBu')
plt.title('Heatmap of Region vs. Attack Type')
plt.xlabel('Attack Type')
plt.ylabel('Region')

plt.show()

# %%
tdf
# Out:
#              eventid  iyear  imonth  iday         country_txt  \
# 0       197000000001   1970       7     2  Dominican Republic
# 1       197000000002   1970       0     0              Mexico
# 2       197001000001   1970       1     0         Philippines
# 3       197001000002   1970       1     0              Greece
# 4       197001000003   1970       1     0               Japan
# ...              ...    ...     ...   ...                 ...
# 181686  201712310022   2017      12    31             Somalia
# 181687  201712310029   2017      12    31               Syria
# 181688  201712310030   2017      12    31         Philippines
# 181689  201712310031   2017      12    31               India
# 181690  201712310032   2017      12    31         Philippines
#
#                          region_txt        provstate           city  \
# 0       Central America & Caribbean              NaN  Santo Domingo
# 1                     North America          Federal    Mexico city
# ...

# %%
filtered_df = tdf[tdf['property'] == 1]

# %%
filtered_df
# Out:
#              eventid  iyear  imonth  iday    country_txt  \
# 3       197001000002   1970       1     0         Greece
# 4       197001000003   1970       1     0          Japan
# 5       197001010002   1970       1     1  United States
# 7       197001020002   1970       1     2  United States
# 8       197001020003   1970       1     2  United States
# ...              ...    ...     ...   ...            ...
# 181681  201712310016   2017      12    31    Philippines
# 181682  201712310017   2017      12    31          Italy
# 181685  201712310020   2017      12    31    Afghanistan
# 181687  201712310029   2017      12    31          Syria
# 181688  201712310030   2017      12    31    Philippines
#
#                         region_txt    provstate           city  \
# 3                   Western Europe       Attica         Athens
# 4                        East Asia      Fukouka        Fukouka
# 5                    North America     Illinois          Cairo
# ...

# %%
tdf
# Out:
#              eventid  iyear  imonth  iday         country_txt  \
# 0       197000000001   1970       7     2  Dominican Republic
# 1       197000000002   1970       0     0              Mexico
# 2       197001000001   1970       1     0         Philippines
# 3       197001000002   1970       1     0              Greece
# 4       197001000003   1970       1     0               Japan
# ...              ...    ...     ...   ...                 ...
# 181686  201712310022   2017      12    31             Somalia
# 181687  201712310029   2017      12    31               Syria
# 181688  201712310030   2017      12    31         Philippines
# 181689  201712310031   2017      12    31               India
# 181690  201712310032   2017      12    31         Philippines
#
#                          region_txt        provstate           city  \
# 0       Central America & Caribbean              NaN  Santo Domingo
# 1                     North America          Federal    Mexico city
# ...

# %%
hr
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
dfm = pd.merge(tdf, hr, on = 'Country', how = 'left')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [49], in <cell line: 1>()
# ----> 1 dfm = pd.merge(tdf, hr, on = 'Country', how = 'left')
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#     110         how=how,
#     111         on=on,
#     112         left_on=left_on,
#     113         right_on=right_on,
#     114         left_index=left_index,
#     115         right_index=right_index,
#     116         sort=sort,
# ...

# %%
tdf1 = tdf.rename(columns = {'country_txt':'Country'})

# %%
tdf1
# Out:
#              eventid  iyear  imonth  iday             Country  \
# 0       197000000001   1970       7     2  Dominican Republic
# 1       197000000002   1970       0     0              Mexico
# 2       197001000001   1970       1     0         Philippines
# 3       197001000002   1970       1     0              Greece
# 4       197001000003   1970       1     0               Japan
# ...              ...    ...     ...   ...                 ...
# 181686  201712310022   2017      12    31             Somalia
# 181687  201712310029   2017      12    31               Syria
# 181688  201712310030   2017      12    31         Philippines
# 181689  201712310031   2017      12    31               India
# 181690  201712310032   2017      12    31         Philippines
#
#                          region_txt        provstate           city  \
# 0       Central America & Caribbean              NaN  Santo Domingo
# 1                     North America          Federal    Mexico city
# ...

# %%
hr
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
dfm = pd.merge(tdf1, hr, on = 'Country', how = 'left')

# %%
dfm
# Out:
#              eventid  iyear  imonth  iday             Country  \
# 0       197000000001   1970       7     2  Dominican Republic
# 1       197000000002   1970       0     0              Mexico
# 2       197001000001   1970       1     0         Philippines
# 3       197001000002   1970       1     0              Greece
# 4       197001000003   1970       1     0               Japan
# ...              ...    ...     ...   ...                 ...
# 181686  201712310022   2017      12    31             Somalia
# 181687  201712310029   2017      12    31               Syria
# 181688  201712310030   2017      12    31         Philippines
# 181689  201712310031   2017      12    31               India
# 181690  201712310032   2017      12    31         Philippines
#
#                          region_txt        provstate           city  \
# 0       Central America & Caribbean              NaN  Santo Domingo
# 1                     North America          Federal    Mexico city
# ...

# %%
dfm2 =dfm.groupby('Happiness Score')['eventid'].count()

# %%
correlation_matrix  =  dfm2.reset_index().corr()

# %%
correlation_matrix
# Out:
#                  Happiness Score   eventid
# Happiness Score         1.000000 -0.059911
# eventid                -0.059911  1.000000

# %%
pivot_table = pd.pivot_table(
    dfm,
    values='Happiness Score',
    index=['Country', 'eventid'], 
    aggfunc='mean'
)

print(pivot_table)
# Out:
#                           Happiness Score
# Country     eventid
# Afghanistan 197305010002            3.575
#             197902140010            3.575
#             197908270005            3.575
#             197909090001            3.575
#             198705310003            3.575
# ...                                   ...
# Zimbabwe    201312290010            4.610
#             201402250012            4.610
#             201707120016            4.610
#             201707180028            4.610
#             201707180043            4.610
#
# [172517 rows x 1 columns]

# %%
correlation_matrix = dfm2.corr()

print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [65], in <cell line: 1>()
# ----> 1 correlation_matrix = dfm2.corr()
#       3 print("Correlation Matrix:")
#       4 print(correlation_matrix)
#
# TypeError: corr() missing 1 required positional argument: 'other'
